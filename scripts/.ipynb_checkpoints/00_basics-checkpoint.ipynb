# %% [markdown]
# # Our first notebook

# %% [markdown]
# Here we are learning Phyton Variables and some useful methods

# %% [markdown]
# ## Variables

# %%
mycal = 2 + 2
mycal
# Out:
# 4

# %%
mystr = "let's do it"

# %%
mystr
# Out:
# "let's do it"

# %%
mydiv = 37 / 3
mydiv
# Out:
# 12.333333333333334

# %%
my-div = 8 / 9
# Out:
#   File "<ipython-input-5-ad4c3460bd00>", line 1
#     my-div = 8 / 9
#                   ^
# SyntaxError: can't assign to operator

# %% [markdown]
# ## Data types

# %%
type(mycal)
# Out:
# int

# %%
type(mydiv)
# Out:
# float

# %%
type(mystr)
# Out:
# str

# %%
help() # to close help you need to press ctrl+C and then ctrl+Enter

# %% [markdown]
# ## Libraries

# %%
import pandas

# %%
% who
# Out:
# mycal	 mydiv	 mystr	 pandas

# %%
anz = pandas.read_csv('../data/gapminder_gdp_oceania.csv')

# %%
anz
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %% [markdown]
# Every piece of information in python has an index, by default this is 0, 1, 2, etc. as in this cell

# %%
anz = pandas.read_csv('../data/gapminder_gdp_oceania.csv', index_col = 'country') # change index to the name of the country

# %%
anz
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
info(anz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a273f8b105c7> in <module>()
# ----> 1 info(anz)
#
# NameError: name 'info' is not defined

# %%
.info(anz)
# Out:
#   File "<ipython-input-19-fb879de56b32>", line 1
#     .info(anz)
#     ^
# SyntaxError: invalid syntax

# %%
africa = pandas.read_csv('../data/gapminder_gdp_africa.csv' , index_col = "country")

# %%
europe = pandas.read_csv('../data/gapminder_gdp_europe.csv' , index_col = "country")

# %%
africa
# Out:
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                      2449.008185     3013.976023     2550.816880
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                        1062.752200      959.601080      949.499064
# Botswana                      851.241141      918.232535      983.653976
# Burkina Faso                  543.255241      617.183465      722.512021
# Burundi                       339.296459      379.564628      355.203227
# Cameroon                     1172.667655     1313.048099     1399.607441
# Central African Republic     1071.310713     1190.844328     1193.068753
# Chad                         1178.665927     1308.495577     1389.817618
# Comoros                      1102.990936     1211.148548     1406.648278
# Congo Dem. Rep.               780.542326      905.860230      896.314634
# Congo Rep.                   2125.621418     2315.056572     2464.783157
# ...

# %%
europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
anz.columns # column names
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
anz.index # row names
# Out:
# Index(['Australia', 'New Zealand'], dtype='object', name='country')

# %%
anz.axes # x-axis is rows and y-axis is columns
# Out:
# [Index(['Australia', 'New Zealand'], dtype='object', name='country'),
#  Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#         'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#         'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#        dtype='object')]

# %%
anz.dtypes # float64 is the default float in pandas
# Out:
# gdpPercap_1952    float64
# gdpPercap_1957    float64
# gdpPercap_1962    float64
# gdpPercap_1967    float64
# gdpPercap_1972    float64
# gdpPercap_1977    float64
# gdpPercap_1982    float64
# gdpPercap_1987    float64
# gdpPercap_1992    float64
# gdpPercap_1997    float64
# gdpPercap_2002    float64
# gdpPercap_2007    float64
# dtype: object

# %%
anz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
anz.shape # number of rows and columns (not counting the index, in this case the country because we made that the index)
# Out:
# (2, 12)

# %%
anz.size # total number of values
# Out:
# 24

# %%
anz.values # array representation of all values
# Out:
# array([[10039.59564, 10949.64959, 12217.22686, 14526.12465, 16788.62948,
#         18334.19751, 19477.00928, 21888.88903, 23424.76683, 26997.93657,
#         30687.75473, 34435.36744],
#        [10556.57566, 12247.39532, 13175.678  , 14463.91893, 16046.03728,
#         16233.7177 , 17632.4104 , 19007.19129, 18363.32494, 21050.41377,
#         23189.80135, 25185.00911]])

# %%
anz.T # transpose: reverse rows and columns
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
anz.ndim # number of dimensions (usually x + y dimension)
# Out:
# 2

# %%
del mycal
% who
# Out:
# africa	 anz	 europe	 mydiv	 mystr	 pandas

# %%
del mydiv
del mystr
% who
# Out:
# africa	 anz	 europe	 pandas

# %%
africa.info() # summary info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, Algeria to Zimbabwe
# Data columns (total 12 columns):
# gdpPercap_1952    52 non-null float64
# gdpPercap_1957    52 non-null float64
# gdpPercap_1962    52 non-null float64
# gdpPercap_1967    52 non-null float64
# gdpPercap_1972    52 non-null float64
# gdpPercap_1977    52 non-null float64
# gdpPercap_1982    52 non-null float64
# gdpPercap_1987    52 non-null float64
# gdpPercap_1992    52 non-null float64
# gdpPercap_1997    52 non-null float64
# gdpPercap_2002    52 non-null float64
# gdpPercap_2007    52 non-null float64
# dtypes: float64(12)
# memory usage: 5.3+ KB

# %%
africa.describe() # summary of statistics per numeric column
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      1252.572466     1385.236062     1598.078825     2050.363801
# std        982.952116     1134.508918     1461.839189     2847.717603
# min        298.846212      335.997115      355.203227      412.977514
# 25%        534.990554      606.954355      673.329046      779.815648
# 50%        987.025569     1024.022987     1133.783677     1210.376379
# 75%       1454.886645     1573.040442     1702.219247     1890.112274
# max       4725.295531     5487.104219     6757.030816    18772.751690
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      2339.615674     2585.938508     2481.592960     2282.668991
# std       3286.853884     4142.398707     3242.632753     2566.531947
# ...

# %%
africa.gdpPercap_1952
# Out:
# country
# Algeria                     2449.008185
# Angola                      3520.610273
# Benin                       1062.752200
# Botswana                     851.241141
# Burkina Faso                 543.255241
# Burundi                      339.296459
# Cameroon                    1172.667655
# Central African Republic    1071.310713
# Chad                        1178.665927
# Comoros                     1102.990936
# Congo Dem. Rep.              780.542326
# Congo Rep.                  2125.621418
# Cote d'Ivoire               1388.594732
# Djibouti                    2669.529475
# Egypt                       1418.822445
# Equatorial Guinea            375.643123
# Eritrea                      328.940557
# Ethiopia                     362.146280
# Gabon                       4293.476475
# Gambia                       485.230659
# Ghana                        911.298937
# Guinea                       510.196492
# Guinea-Bissau                299.850319
# ...

# %%
africa.gdpPercap_1952.describe() # summary of statistics for a specific column
# Out:
# count      52.000000
# mean     1252.572466
# std       982.952116
# min       298.846212
# 25%       534.990554
# 50%       987.025569
# 75%      1454.886645
# max      4725.295531
# Name: gdpPercap_1952, dtype: float64

# %%
africa.head() # first n rows (5 by default)
# Out:
#               gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria          2449.008185     3013.976023     2550.816880     3246.991771
# Angola           3520.610273     3827.940465     4269.276742     5522.776375
# Benin            1062.752200      959.601080      949.499064     1035.831411
# Botswana          851.241141      918.232535      983.653976     1214.709294
# Burkina Faso      543.255241      617.183465      722.512021      794.826560
#
#               gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria          4182.663766     4910.416756     5745.160213     5681.358539
# Angola           5473.288005     3008.647355     2756.953672     2430.208311
# Benin            1085.796879     1029.161251     1277.897616     1225.856010
# Botswana         2263.611114     3214.857818     4551.142150     6205.883850
# Burkina Faso      854.735976      743.387037      807.198586      912.063142
#
# ...

# %%
africa.tail() # last n rows (5 by default)
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Togo          859.808657      925.908320     1067.534810     1477.596760
# Tunisia      1468.475631     1395.232468     1660.303210     1932.360167
# Uganda        734.753484      774.371069      767.271740      908.918522
# Zambia       1147.388831     1311.956766     1452.725766     1777.077318
# Zimbabwe      406.884115      518.764268      527.272182      569.795071
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Togo         1649.660188     1532.776998     1344.577953     1202.201361
# Tunisia      2753.285994     3120.876811     3560.233174     3810.419296
# Uganda        950.735869      843.733137      682.266227      617.724406
# Zambia       1773.498265     1588.688299     1408.678565     1213.315116
# Zimbabwe      799.362176      685.587682      788.855041      706.157306
#
# ...

# %%
africa.head(n=3) # first 3 rows
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria     2449.008185     3013.976023     2550.816880     3246.991771
# Angola      3520.610273     3827.940465     4269.276742     5522.776375
# Benin       1062.752200      959.601080      949.499064     1035.831411
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria     4182.663766     4910.416756     5745.160213     5681.358539
# Angola      5473.288005     3008.647355     2756.953672     2430.208311
# Benin       1085.796879     1029.161251     1277.897616     1225.856010
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria     5023.216647     4797.295051     5288.040382     6223.367465
# Angola      2627.845685     2277.140884     2773.287312     4797.231267
# Benin       1191.207681     1232.975292     1372.877931     1441.284873

# %%
americas = pandas.read_csv('../data/gapminder_gdp_americas.csv' , index_col = "country")

# %%
americas
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
americas.head(n=3) # you can also type americas.head(3) because n is the first option of head
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# Argentina     9139.671389     9308.418710    10967.281950     8797.640716
# Bolivia       2753.691490     2961.699694     3326.143191     3413.262690
# Brazil        7807.095818     6950.283021     7957.980824     8131.212843
#
#            gdpPercap_2007
# country
# Argentina    12779.379640
# ...

# %%
americas.tail(n=3) # you can also type americas.tail(3) because n is the first option of tail
# Out:
#               continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# United States  Americas    13990.482080    14847.127120    16173.145860
# Uruguay        Americas     5716.766744     6150.772969     5603.357717
# Venezuela      Americas     7689.799761     9802.466526     8422.974165
#
#                gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# United States    19530.365570    21806.035940    24072.632130    25009.559140
# Uruguay           5444.619620     5703.408898     6504.339663     6920.223051
# Venezuela         9541.474188    10505.259660    13143.950950    11152.410110
#
#                gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# United States    29884.350410    32003.932240    35767.433030    39097.099550
# Uruguay           7452.398969     8137.004775     9230.240708     7727.002004
# Venezuela         9883.584648    10733.926310    10165.495180     8605.047831
#
# ...

# %%
americas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
americas.T
# Out:
# country        Argentina   Bolivia    Brazil    Canada     Chile  Colombia  \
# continent       Americas  Americas  Americas  Americas  Americas  Americas
# gdpPercap_1952   5911.32   2677.33   2108.94   11367.2   3939.98   2144.12
# gdpPercap_1957   6856.86   2127.69   2487.37     12490   4315.62   2323.81
# gdpPercap_1962   7133.17   2180.97   3336.59   13462.5   4519.09   2492.35
# gdpPercap_1967   8052.95   2586.89   3429.86   16076.6   5106.65   2678.73
# gdpPercap_1972   9443.04   2980.33   4985.71   18970.6   5494.02   3264.66
# gdpPercap_1977     10079    3548.1   6660.12   22090.9   4756.76   3815.81
# gdpPercap_1982    8997.9   3156.51   7030.84   22898.8   5095.67   4397.58
# gdpPercap_1987   9139.67   2753.69    7807.1   26626.5   5547.06   4903.22
# gdpPercap_1992   9308.42    2961.7   6950.28   26342.9   7596.13   5444.65
# gdpPercap_1997   10967.3   3326.14   7957.98   28954.9   10118.1   6117.36
# ...

# %%
processed = americas.T.tail(n=3).T # you could also make an intermediate variable instead of doing everything in one step

# %%
processed.columns
# Out:
# Index(['gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'], dtype='object')

# %%
processed.columns.format() # you could save this as another variable and use it for further analyses
# Out:
# ['gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007']

# %%
europe.iloc # subset a part of the dataframe using the row index
europe.loc # subset a part of the dataframe using the row name
favoritecountry = europe.loc["Belgium"]

# %%
favoritecountry
# Out:
# gdpPercap_1952     8343.105127
# gdpPercap_1957     9714.960623
# gdpPercap_1962    10991.206760
# gdpPercap_1967    13149.041190
# gdpPercap_1972    16672.143560
# gdpPercap_1977    19117.974480
# gdpPercap_1982    20979.845890
# gdpPercap_1987    22525.563080
# gdpPercap_1992    25575.570690
# gdpPercap_1997    27561.196630
# gdpPercap_2002    30485.883750
# gdpPercap_2007    33692.605080
# Name: Belgium, dtype: float64

# %%
europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
greece = europe.loc["Greece"]

# %%
greece
# Out:
# gdpPercap_1952     3530.690067
# gdpPercap_1957     4916.299889
# gdpPercap_1962     6017.190733
# gdpPercap_1967     8513.097016
# gdpPercap_1972    12724.829570
# gdpPercap_1977    14195.524280
# gdpPercap_1982    15268.420890
# gdpPercap_1987    16120.528390
# gdpPercap_1992    17541.496340
# gdpPercap_1997    18747.698140
# gdpPercap_2002    22514.254800
# gdpPercap_2007    27538.411880
# Name: Greece, dtype: float64

# %%
greece.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-76bff8c6c161> in <module>()
# ----> 1 greece.index()
#
# TypeError: 'Index' object is not callable

# %%
greece.index
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
gdpgreece = greece.loc["gdpPercap_2007"]

# %%
gdpgreece
# Out:
# 27538.41188

# %%
iceland = europe.loc["Iceland"]

# %%
iceland
# Out:
# gdpPercap_1952     7267.688428
# gdpPercap_1957     9244.001412
# gdpPercap_1962    10350.159060
# gdpPercap_1967    13319.895680
# gdpPercap_1972    15798.063620
# gdpPercap_1977    19654.962470
# gdpPercap_1982    23269.607500
# gdpPercap_1987    26923.206280
# gdpPercap_1992    25144.392010
# gdpPercap_1997    28061.099660
# gdpPercap_2002    31163.201960
# gdpPercap_2007    36180.789190
# Name: Iceland, dtype: float64

# %%
gdpiceland = iceland.loc["gdpPercap_1952"]

# %%
gdpiceland
# Out:
# 7267.688428

# %%
europe.loc['Greece','gdpPercap_2007']
# Out:
# 27538.41188

# %%
europe.loc[['Iceland','Greece'],['gdpPercap_1952','gdpPercap_2007']] # first subset the rows, then the years
# Out:
#          gdpPercap_1952  gdpPercap_2007
# country
# Iceland     7267.688428     36180.78919
# Greece      3530.690067     27538.41188
